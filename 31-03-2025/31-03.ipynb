# %%
import csv
import numpy as np
arreglo=np.array([])
type(arreglo)
#with open("C:\\Users\\usuario\\Dropbox\\sena2025\\Trimestre1-Febrero10-Abril25\\2996881_Analitica\\datos2.csv") as mycsv:
with open("employees.csv") as mycsv:
    data=csv.reader(mycsv)
    print(data)
    print(type(data))
    for x in data:
        print(x)
        arreglo=np.append(arreglo,x)
    
print(arreglo)
arreglo = arreglo.reshape(51,11)
arreglo
print(type(arreglo))
# Out:
# ...
# <class '_csv.reader'>
# ['EMPLOYEE_ID', 'FIRST_NAME', 'LAST_NAME', 'EMAIL', 'PHONE_NUMBER', 'HIRE_DATE', 'JOB_ID', 'SALARY', 'COMMISSION_PCT', 'MANAGER_ID', 'DEPARTMENT_ID']
# ['198', 'Donald', 'OConnell', 'DOCONNEL', '650.507.9833', '21-JUN-07', 'SH_CLERK', '2600', ' - ', '124', '50']
# ['199', 'Douglas', 'Grant', 'DGRANT', '650.507.9844', '13-JAN-08', 'SH_CLERK', '2600', ' - ', '124', '50']
# ['200', 'Jennifer', 'Whalen', 'JWHALEN', '515.123.4444', '17-SEP-03', 'AD_ASST', '4400', ' - ', '101', '10']
# ['201', 'Michael', 'Hartstein', 'MHARTSTE', '515.123.5555', '17-FEB-04', 'MK_MAN', '13000', ' - ', '100', '20']
# ['202', 'Pat', 'Fay', 'PFAY', '603.123.6666', '17-AUG-05', 'MK_REP', '6000', ' - ', '201', '20']
# ['203', 'Susan', 'Mavris', 'SMAVRIS', '515.123.7777', '07-JUN-02', 'HR_REP', '6500', ' - ', '101', '40']
# ['204', 'Hermann', 'Baer', 'HBAER', '515.123.8888', '07-JUN-02', 'PR_REP', '10000', ' - ', '101', '70']
# ...

# %% [markdown]
# # Análisis de Salarios

# %%
salarios = arreglo[1:, 7]
salariosnum = salarios.astype(int)
print("Suma de los salarios: ", np.sum(salariosnum))
print("Promedio de los salarios: ",np.mean(salariosnum))
print("Menor salario:",np.min(salariosnum))
print("Mayor salario:",np.max(salariosnum))

# %% [markdown]
# # Agrupación por Departamento

# %%
departamentos = arreglo[1:,10]
unique_depts = np.unique(departamentos)
print(departamentos)
print(unique_depts)
print(salariosnum)
# Out:
# ['50' '50' '10' '20' '20' '40' '70' '110' '110' '90' '90' '90' '60' '60'
#  '60' '60' '60' '100' '100' '100' '100' '100' '100' '30' '30' '30' '30'
#  '30' '30' '50' '50' '50' '50' '50' '50' '50' '50' '50' '50' '50' '50'
#  '50' '50' '50' '50' '50' '50' '50' '50' '50']
# ['10' '100' '110' '20' '30' '40' '50' '60' '70' '90']
# [ 2600  2600  4400 13000  6000  6500 10000 12008  8300 24000 17000 17000
#   9000  6000  4800  4800  4200 12008  9000  8200  7700  7800  6900 11000
#   3100  2900  2800  2600  2500  8000  8200  7900  6500  5800  3200  2700
#   2400  2200  3300  2800  2500  2100  3300  2900  2400  2200  3600  3200
#   2700  2500]
